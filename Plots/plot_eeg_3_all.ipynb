# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# # Data dir

# %%
DATA_DIR = os.path.join("..", "..")
DATA_DIR = os.path.join(DATA_DIR, "Data")
DATA_DIR = os.path.join(DATA_DIR, "EEG")
FIGURES_DIR = os.path.join("Figures", "EEG3")

# %% [markdown]
# # Functions for Plotting

# %%
def one_scale(ax1, index1, index2, index3, data1, data2, data3, name1, name2, name3, y_label):

    lns1 = ax1.plot(index1, data1, color='b', linestyle = '--')
    lns2 = ax1.plot(index2, data2, color='r')
    lns3 = ax1.plot(index3, data3, color='g')
    
    lns = lns1 + lns2 + lns3
        
    ax1.legend(lns, [name1,name2,name3], loc='best')

    ax1.set_xticklabels([])
    
    #ax1.set_ylim(data_min, data_max)
    ax1.set_ylabel(y_label)
    
    for t in ax1.get_yticklabels():
        t.set_color('black')
        
    return ax1

# %%
def plot_metric(df_low, df_high, df_medium, metric, fig_name, title=""):
    
    plt.rcParams["figure.figsize"] = (15,6)
    plt.rcParams.update({'font.size': 22})
    
    ax = plt.subplot(1, 1, 1)
    ax1 = one_scale(ax, df_low.index, df_high.index, df_medium.index, df_low[metric], df_high[metric], df_medium[metric],
                         'low', 'high', 'medium', metric)

    plt.title(title)
    plt.tight_layout()
    
    plt.savefig(os.path.join(FIGURES_DIR, fig_name + '.png'))

# %% [markdown]
# # Read data

# %%
df_low_all = pd.DataFrame()
df_high_all = pd.DataFrame()
df_medium_all = pd.DataFrame()

# %%
filename = os.path.join(DATA_DIR, "D1r1_MO.csv")
df_low = pd.read_csv(filename, sep=';', low_memory=False)

filename = os.path.join(DATA_DIR, "D1r3_MO.csv")
df_high = pd.read_csv(filename, sep=';', low_memory=False)

filename = os.path.join(DATA_DIR, "D1r2_MO.csv")
df_medium = pd.read_csv(filename, sep=';', low_memory=False)

df_low = df_low[df_low.vigilance < 1]
df_high = df_high[df_high.vigilance < 1]
df_medium = df_medium[df_medium.vigilance < 1]

min_num = min([len(df_low.index), len(df_high.index), len(df_medium.index)])
number_of_rows = min_num

df_low_all['WL1'] = df_low['workload']
df_low_all['S1'] = df_low['stress']
df_low_all['V1'] = df_low['vigilance']
df_high_all['WL1'] = df_high['workload']
df_high_all['S1'] = df_high['stress']
df_high_all['V1'] = df_high['vigilance']
df_medium_all['WL1'] = df_medium['workload']
df_medium_all['S1'] = df_medium['stress']
df_medium_all['V1'] = df_medium['vigilance']

# %%
filename = os.path.join(DATA_DIR, "D1r6_EI.csv")
df_low = pd.read_csv(filename, sep=';', low_memory=False)

filename = os.path.join(DATA_DIR, "D1r4_EI.csv")
df_high = pd.read_csv(filename, sep=';', low_memory=False)

filename = os.path.join(DATA_DIR, "D1r5_EI.csv")
df_medium = pd.read_csv(filename, sep=';', low_memory=False)

df_low = df_low[df_low.vigilance < 1]
df_high = df_high[df_high.vigilance < 1]
df_medium = df_medium[df_medium.vigilance < 1]

min_num = min([len(df_low.index), len(df_high.index), len(df_medium.index)])
if min_num < number_of_rows:
    number_of_rows = min_num

df_low_all['WL2'] = df_low['workload']
df_low_all['S2'] = df_low['stress']
df_low_all['V2'] = df_low['vigilance']
df_high_all['WL2'] = df_high['workload']
df_high_all['S2'] = df_high['stress']
df_high_all['V2'] = df_high['vigilance']
df_medium_all['WL2'] = df_medium['workload']
df_medium_all['S2'] = df_medium['stress']
df_medium_all['V2'] = df_medium['vigilance']

# %%
filename = os.path.join(DATA_DIR, "D2r3_KV.csv")
df_low = pd.read_csv(filename, sep=';', low_memory=False)

filename = os.path.join(DATA_DIR, "D2r1_KV.csv")
df_high = pd.read_csv(filename, sep=';', low_memory=False)

filename = os.path.join(DATA_DIR, "D2r2_KV.csv")
df_medium = pd.read_csv(filename, sep=';', low_memory=False)

df_low = df_low[df_low.vigilance < 1]
df_high = df_high[df_high.vigilance < 1]
df_medium = df_medium[df_medium.vigilance < 1]

min_num = min([len(df_low.index), len(df_high.index), len(df_medium.index)])
if min_num < number_of_rows:
    number_of_rows = min_num

df_low_all['WL3'] = df_low['workload']
df_low_all['S3'] = df_low['stress']
df_low_all['V3'] = df_low['vigilance']
df_high_all['WL3'] = df_high['workload']
df_high_all['S3'] = df_high['stress']
df_high_all['V3'] = df_high['vigilance']
df_medium_all['WL3'] = df_medium['workload']
df_medium_all['S3'] = df_medium['stress']
df_medium_all['V3'] = df_medium['vigilance']

# %%
filename = os.path.join(DATA_DIR, "D2r4_UO.csv")
df_low = pd.read_csv(filename, sep=';', low_memory=False)

filename = os.path.join(DATA_DIR, "D2r6_UO.csv")
df_high = pd.read_csv(filename, sep=';', low_memory=False)

filename = os.path.join(DATA_DIR, "D2r5_UO.csv")
df_medium = pd.read_csv(filename, sep=';', low_memory=False)

df_low = df_low[df_low.vigilance < 1]
df_high = df_high[df_high.vigilance < 1]
df_medium = df_medium[df_medium.vigilance < 1]

min_num = min([len(df_low.index), len(df_high.index), len(df_medium.index)])
if min_num < number_of_rows:
    number_of_rows = min_num

df_low_all['WL4'] = df_low['workload']
df_low_all['S4'] = df_low['stress']
df_low_all['V4'] = df_low['vigilance']
df_high_all['WL4'] = df_high['workload']
df_high_all['S4'] = df_high['stress']
df_high_all['V4'] = df_high['vigilance']
df_medium_all['WL4'] = df_medium['workload']
df_medium_all['S4'] = df_medium['stress']
df_medium_all['V4'] = df_medium['vigilance']

# %%
filename = os.path.join(DATA_DIR, "D3r1_KB.csv")
df_low = pd.read_csv(filename, sep=';', low_memory=False)

filename = os.path.join(DATA_DIR, "D3r2_KB.csv")
df_high = pd.read_csv(filename, sep=';', low_memory=False)

filename = os.path.join(DATA_DIR, "D3r3_KB.csv")
df_medium = pd.read_csv(filename, sep=';', low_memory=False)

df_low = df_low[df_low.vigilance < 1]
df_high = df_high[df_high.vigilance < 1]
df_medium = df_medium[df_medium.vigilance < 1]

min_num = min([len(df_low.index), len(df_high.index), len(df_medium.index)])
if min_num < number_of_rows:
    number_of_rows = min_num

df_low_all['WL5'] = df_low['workload']
df_low_all['S5'] = df_low['stress']
df_low_all['V5'] = df_low['vigilance']
df_high_all['WL5'] = df_high['workload']
df_high_all['S5'] = df_high['stress']
df_high_all['V5'] = df_high['vigilance']
df_medium_all['WL5'] = df_medium['workload']
df_medium_all['S5'] = df_medium['stress']
df_medium_all['V5'] = df_medium['vigilance']

# %%
filename = os.path.join(DATA_DIR, "D3r5_PF.csv")
df_low = pd.read_csv(filename, sep=';', low_memory=False)

filename = os.path.join(DATA_DIR, "D3r4_PF.csv")
df_high = pd.read_csv(filename, sep=';', low_memory=False)

filename = os.path.join(DATA_DIR, "D3r6_PF.csv")
df_medium = pd.read_csv(filename, sep=';', low_memory=False)

df_low = df_low[df_low.vigilance < 1]
df_high = df_high[df_high.vigilance < 1]
df_medium = df_medium[df_medium.vigilance < 1]

min_num = min([len(df_low.index), len(df_high.index), len(df_medium.index)])
if min_num < number_of_rows:
    number_of_rows = min_num

df_low_all['WL6'] = df_low['workload']
df_low_all['S6'] = df_low['stress']
df_low_all['V6'] = df_low['vigilance']
df_high_all['WL6'] = df_high['workload']
df_high_all['S6'] = df_high['stress']
df_high_all['V6'] = df_high['vigilance']
df_medium_all['WL6'] = df_medium['workload']
df_medium_all['S6'] = df_medium['stress']
df_medium_all['V6'] = df_medium['vigilance']

# %%
filename = os.path.join(DATA_DIR, "D4r3_AL.csv")
df_low = pd.read_csv(filename, sep=';', low_memory=False)

filename = os.path.join(DATA_DIR, "D4r2_AL.csv")
df_high = pd.read_csv(filename, sep=';', low_memory=False)

filename = os.path.join(DATA_DIR, "D4r1_AL.csv")
df_medium = pd.read_csv(filename, sep=';', low_memory=False)

df_low = df_low[df_low.vigilance < 1]
df_high = df_high[df_high.vigilance < 1]
df_medium = df_medium[df_medium.vigilance < 1]

min_num = min([len(df_low.index), len(df_high.index), len(df_medium.index)])
if min_num < number_of_rows:
    number_of_rows = min_num

df_low_all['WL7'] = df_low['workload']
df_low_all['S7'] = df_low['stress']
df_low_all['V7'] = df_low['vigilance']
df_high_all['WL7'] = df_high['workload']
df_high_all['S7'] = df_high['stress']
df_high_all['V7'] = df_high['vigilance']
df_medium_all['WL7'] = df_medium['workload']
df_medium_all['S7'] = df_medium['stress']
df_medium_all['V7'] = df_medium['vigilance']

# %%
filename = os.path.join(DATA_DIR, "D4r4_IH.csv")
df_low = pd.read_csv(filename, sep=';', low_memory=False)

filename = os.path.join(DATA_DIR, "D4r5_IH.csv")
df_high = pd.read_csv(filename, sep=';', low_memory=False)

filename = os.path.join(DATA_DIR, "D4r6_IH.csv")
df_medium = pd.read_csv(filename, sep=';', low_memory=False)

df_low = df_low[df_low.vigilance < 1]
df_high = df_high[df_high.vigilance < 1]
df_medium = df_medium[df_medium.vigilance < 1]

min_num = min([len(df_low.index), len(df_high.index), len(df_medium.index)])
if min_num < number_of_rows:
    number_of_rows = min_num

df_low_all['WL8'] = df_low['workload']
df_low_all['S8'] = df_low['stress']
df_low_all['V8'] = df_low['vigilance']
df_high_all['WL8'] = df_high['workload']
df_high_all['S8'] = df_high['stress']
df_high_all['V8'] = df_high['vigilance']
df_medium_all['WL8'] = df_medium['workload']
df_medium_all['S8'] = df_medium['stress']
df_medium_all['V8'] = df_medium['vigilance']

# %%
filename = os.path.join(DATA_DIR, "D5r2_RI.csv")
df_low = pd.read_csv(filename, sep=';', low_memory=False)

filename = os.path.join(DATA_DIR, "D5r3_RI.csv")
df_high = pd.read_csv(filename, sep=';', low_memory=False)

filename = os.path.join(DATA_DIR, "D5r1_RI.csv")
df_medium = pd.read_csv(filename, sep=';', low_memory=False)

df_low = df_low[df_low.vigilance < 1]
df_high = df_high[df_high.vigilance < 1]
df_medium = df_medium[df_medium.vigilance < 1]

min_num = min([len(df_low.index), len(df_high.index), len(df_medium.index)])
if min_num < number_of_rows:
    number_of_rows = min_num

df_low_all['WL9'] = df_low['workload']
df_low_all['S9'] = df_low['stress']
df_low_all['V9'] = df_low['vigilance']
df_high_all['WL9'] = df_high['workload']
df_high_all['S9'] = df_high['stress']
df_high_all['V9'] = df_high['vigilance']
df_medium_all['WL9'] = df_medium['workload']
df_medium_all['S9'] = df_medium['stress']
df_medium_all['V9'] = df_medium['vigilance']

# %%
filename = os.path.join(DATA_DIR, "D5r5_JO.csv")
df_low = pd.read_csv(filename, sep=';', low_memory=False)

filename = os.path.join(DATA_DIR, "D5r4_JO.csv")
df_high = pd.read_csv(filename, sep=';', low_memory=False)

filename = os.path.join(DATA_DIR, "D5r6_JO.csv")
df_medium = pd.read_csv(filename, sep=';', low_memory=False)

df_low = df_low[df_low.vigilance < 1]
df_high = df_high[df_high.vigilance < 1]
df_medium = df_medium[df_medium.vigilance < 1]

min_num = min([len(df_low.index), len(df_high.index), len(df_medium.index)])
if min_num < number_of_rows:
    number_of_rows = min_num

df_low_all['WL10'] = df_low['workload']
df_low_all['S10'] = df_low['stress']
df_low_all['V10'] = df_low['vigilance']
df_high_all['WL10'] = df_high['workload']
df_high_all['S10'] = df_high['stress']
df_high_all['V10'] = df_high['vigilance']
df_medium_all['WL10'] = df_medium['workload']
df_medium_all['S10'] = df_medium['stress']
df_medium_all['V10'] = df_medium['vigilance']

# %%
filename = os.path.join(DATA_DIR, "D6r3_AE.csv")
df_low = pd.read_csv(filename, sep=';', low_memory=False)

filename = os.path.join(DATA_DIR, "D6r2_AE.csv")
df_high = pd.read_csv(filename, sep=';', low_memory=False)

filename = os.path.join(DATA_DIR, "D6r1_AE.csv")
df_medium = pd.read_csv(filename, sep=';', low_memory=False)

df_low = df_low[df_low.vigilance < 1]
df_high = df_high[df_high.vigilance < 1]
df_medium = df_medium[df_medium.vigilance < 1]

min_num = min([len(df_low.index), len(df_high.index), len(df_medium.index)])
if min_num < number_of_rows:
    number_of_rows = min_num

df_low_all['WL11'] = df_low['workload']
df_low_all['S11'] = df_low['stress']
df_low_all['V11'] = df_low['vigilance']
df_high_all['WL11'] = df_high['workload']
df_high_all['S11'] = df_high['stress']
df_high_all['V11'] = df_high['vigilance']
df_medium_all['WL11'] = df_medium['workload']
df_medium_all['S11'] = df_medium['stress']
df_medium_all['V11'] = df_medium['vigilance']

# %%
filename = os.path.join(DATA_DIR, "D6r5_HC.csv")
df_low = pd.read_csv(filename, sep=';', low_memory=False)

filename = os.path.join(DATA_DIR, "D6r6_HC.csv")
df_high = pd.read_csv(filename, sep=';', low_memory=False)

filename = os.path.join(DATA_DIR, "D6r4_HC.csv")
df_medium = pd.read_csv(filename, sep=';', low_memory=False)

df_low = df_low[df_low.vigilance < 1]
df_high = df_high[df_high.vigilance < 1]
df_medium = df_medium[df_medium.vigilance < 1]

min_num = min([len(df_low.index), len(df_high.index), len(df_medium.index)])
if min_num < number_of_rows:
    number_of_rows = min_num

df_low_all['WL12'] = df_low['workload']
df_low_all['S12'] = df_low['stress']
df_low_all['V12'] = df_low['vigilance']
df_high_all['WL12'] = df_high['workload']
df_high_all['S12'] = df_high['stress']
df_high_all['V12'] = df_high['vigilance']
df_medium_all['WL12'] = df_medium['workload']
df_medium_all['S12'] = df_medium['stress']
df_medium_all['V12'] = df_medium['vigilance']

# %%
filename = os.path.join(DATA_DIR, "D7r3_LS.csv")
df_low = pd.read_csv(filename, sep=';', low_memory=False)

filename = os.path.join(DATA_DIR, "D7r2_LS.csv")
df_high = pd.read_csv(filename, sep=';', low_memory=False)

filename = os.path.join(DATA_DIR, "D7r1_LS.csv")
df_medium = pd.read_csv(filename, sep=';', low_memory=False)

df_low = df_low[df_low.vigilance < 1]
df_high = df_high[df_high.vigilance < 1]
df_medium = df_medium[df_medium.vigilance < 1]

min_num = min([len(df_low.index), len(df_high.index), len(df_medium.index)])
if min_num < number_of_rows:
    number_of_rows = min_num

df_low_all['WL13'] = df_low['workload']
df_low_all['S13'] = df_low['stress']
df_low_all['V13'] = df_low['vigilance']
df_high_all['WL13'] = df_high['workload']
df_high_all['S13'] = df_high['stress']
df_high_all['V13'] = df_high['vigilance']
df_medium_all['WL13'] = df_medium['workload']
df_medium_all['S13'] = df_medium['stress']
df_medium_all['V13'] = df_medium['vigilance']

# %%
filename = os.path.join(DATA_DIR, "D7r4_ML.csv")
df_low = pd.read_csv(filename, sep=';', low_memory=False)

filename = os.path.join(DATA_DIR, "D7r5_ML.csv")
df_high = pd.read_csv(filename, sep=';', low_memory=False)

filename = os.path.join(DATA_DIR, "D7r6_ML.csv")
df_medium = pd.read_csv(filename, sep=';', low_memory=False)

df_low = df_low[df_low.vigilance < 1]
df_high = df_high[df_high.vigilance < 1]
df_medium = df_medium[df_medium.vigilance < 1]

min_num = min([len(df_low.index), len(df_high.index), len(df_medium.index)])
if min_num < number_of_rows:
    number_of_rows = min_num

df_low_all['WL14'] = df_low['workload']
df_low_all['S14'] = df_low['stress']
df_low_all['V14'] = df_low['vigilance']
df_high_all['WL14'] = df_high['workload']
df_high_all['S14'] = df_high['stress']
df_high_all['V14'] = df_high['vigilance']
df_medium_all['WL14'] = df_medium['workload']
df_medium_all['S14'] = df_medium['stress']
df_medium_all['V14'] = df_medium['vigilance']

# %%
filename = os.path.join(DATA_DIR, "D8r6_AK.csv")
df_low = pd.read_csv(filename, sep=';', low_memory=False)

filename = os.path.join(DATA_DIR, "D8r5_AK.csv")
df_high = pd.read_csv(filename, sep=';', low_memory=False)

df_low = df_low[df_low.vigilance < 1]
df_high = df_high[df_high.vigilance < 1]

min_num = min([len(df_low.index), len(df_high.index)])
if min_num < number_of_rows:
    number_of_rows = min_num

df_low_all['WL15'] = df_low['workload']
df_low_all['S15'] = df_low['stress']
df_low_all['V15'] = df_low['vigilance']
df_high_all['WL15'] = df_high['workload']
df_high_all['S15'] = df_high['stress']
df_high_all['V15'] = df_high['vigilance']

# %%
filename = os.path.join(DATA_DIR, "D9r2_RE.csv")
df_low = pd.read_csv(filename, sep=';', low_memory=False)

filename = os.path.join(DATA_DIR, "D9r1_RE.csv")
df_high = pd.read_csv(filename, sep=';', low_memory=False)

filename = os.path.join(DATA_DIR, "D9r3_RE.csv")
df_medium = pd.read_csv(filename, sep=';', low_memory=False)

df_low = df_low[df_low.vigilance < 1]
df_high = df_high[df_high.vigilance < 1]
df_medium = df_medium[df_medium.vigilance < 1]

min_num = min([len(df_low.index), len(df_high.index), len(df_medium.index)])
if min_num < number_of_rows:
    number_of_rows = min_num

df_low_all['WL16'] = df_low['workload']
df_low_all['S16'] = df_low['stress']
df_low_all['V16'] = df_low['vigilance']
df_high_all['WL16'] = df_high['workload']
df_high_all['S16'] = df_high['stress']
df_high_all['V16'] = df_high['vigilance']
df_medium_all['WL16'] = df_medium['workload']
df_medium_all['S16'] = df_medium['stress']
df_medium_all['V16'] = df_medium['vigilance']

# %%
filename = os.path.join(DATA_DIR, "D9r6_SV.csv")
df_low = pd.read_csv(filename, sep=';', low_memory=False)

filename = os.path.join(DATA_DIR, "D9r4_SV.csv")
df_high = pd.read_csv(filename, sep=';', low_memory=False)

filename = os.path.join(DATA_DIR, "D9r5_SV.csv")
df_medium = pd.read_csv(filename, sep=';', low_memory=False)

df_low = df_low[df_low.vigilance < 1]
df_high = df_high[df_high.vigilance < 1]
df_medium = df_medium[df_medium.vigilance < 1]

min_num = min([len(df_low.index), len(df_high.index), len(df_medium.index)])
if min_num < number_of_rows:
    number_of_rows = min_num

df_low_all['WL17'] = df_low['workload']
df_low_all['S17'] = df_low['stress']
df_low_all['V17'] = df_low['vigilance']
df_high_all['WL17'] = df_high['workload']
df_high_all['S17'] = df_high['stress']
df_high_all['V17'] = df_high['vigilance']
df_medium_all['WL17'] = df_medium['workload']
df_medium_all['S17'] = df_medium['stress']
df_medium_all['V17'] = df_medium['vigilance']

# %%
def getMean17(v1, v2, v3, v4, v5, v6, v7, v8, v9, v10, v11, v12, v13, v14, v15, v16, v17):
    
    return (v1 + v2 + v3 + v4 + v5 + v6 + v7 + v8 + v9 + v10 + v11 + v12 + v13 + v14 + v15 + v16 + v17)/17

# %%
def getMean16(v1, v2, v3, v4, v5, v6, v7, v8, v9, v10, v11, v12, v13, v14, v15, v16):
    
    return (v1 + v2 + v3 + v4 + v5 + v6 + v7 + v8 + v9 + v10 + v11 + v12 + v13 + v14 + v15 + v16)/16

# %%
#fill the null rows with the mean of respective columns
df_low_all = df_low_all.fillna(df_low_all.mean())
df_high_all = df_high_all.fillna(df_high_all.mean())
df_medium_all = df_medium_all.fillna(df_medium_all.mean())

# %%
df_low_all['WL_mean'] = df_low_all.apply(lambda row: getMean17(row['WL1'], row['WL2'], row['WL3'], row['WL4'],
                                                       row['WL5'], row['WL6'], row['WL7'], row['WL8'],
                                                       row['WL9'], row['WL10'], row['WL11'], row['WL12'],
                                                       row['WL13'], row['WL14'], row['WL15'], row['WL16'], row['WL17']
                                                              ),
                                 axis=1)

# %%
df_high_all['WL_mean'] = df_high_all.apply(lambda row: getMean17(row['WL1'], row['WL2'], row['WL3'], row['WL4'],
                                                       row['WL5'], row['WL6'], row['WL7'], row['WL8'],
                                                       row['WL9'], row['WL10'], row['WL11'], row['WL12'],
                                                       row['WL13'], row['WL14'], row['WL15'], row['WL16'], row['WL17']
                                                              ),
                                 axis=1)

# %%
df_medium_all['WL_mean'] = df_medium_all.apply(lambda row: getMean16(row['WL1'], row['WL2'], row['WL3'], row['WL4'],
                                                       row['WL5'], row['WL6'], row['WL7'], row['WL8'],
                                                       row['WL9'], row['WL10'], row['WL11'], row['WL12'],
                                                       row['WL13'], row['WL14'],           row['WL16'], row['WL17']
                                                              ),
                                 axis=1)

# %%
df_low_all['S_mean'] = df_low_all.apply(lambda row: getMean17(row['S1'], row['S2'], row['S3'], row['S4'],
                                                       row['S5'], row['S6'], row['S7'], row['S8'],
                                                       row['S9'], row['S10'], row['S11'], row['S12'],
                                                       row['S13'], row['S14'], row['S15'], row['S16'], row['S17']
                                                              ),
                                 axis=1)

# %%
df_high_all['S_mean'] = df_high_all.apply(lambda row: getMean17(row['S1'], row['S2'], row['S3'], row['S4'],
                                                       row['S5'], row['S6'], row['S7'], row['S8'],
                                                       row['S9'], row['S10'], row['S11'], row['S12'],
                                                       row['S13'], row['S14'], row['S15'], row['S16'], row['S17']
                                                              ),
                                 axis=1)

# %%
df_medium_all['S_mean'] = df_medium_all.apply(lambda row: getMean16(row['S1'], row['S2'], row['S3'], row['S4'],
                                                       row['S5'], row['S6'], row['S7'], row['S8'],
                                                       row['S9'], row['S10'], row['S11'], row['S12'],
                                                       row['S13'], row['S14'],           row['S16'], row['S17']
                                                              ),
                                 axis=1)

# %%
df_low_all['V_mean'] = df_low_all.apply(lambda row: getMean17(row['V1'], row['V2'], row['V3'], row['V4'],
                                                       row['V5'], row['V6'], row['V7'], row['V8'],
                                                       row['V9'], row['V10'], row['V11'], row['V12'],
                                                       row['V13'], row['V14'], row['V15'], row['V16'], row['V17']
                                                              ),
                                 axis=1)

# %%
df_high_all['V_mean'] = df_high_all.apply(lambda row: getMean17(row['V1'], row['V2'], row['V3'], row['V4'],
                                                       row['V5'], row['V6'], row['V7'], row['V8'],
                                                       row['V9'], row['V10'], row['V11'], row['V12'],
                                                       row['V13'], row['V14'], row['V15'], row['V16'], row['V17']
                                                              ),
                                 axis=1)

# %%
df_medium_all['V_mean'] = df_medium_all.apply(lambda row: getMean16(row['V1'], row['V2'], row['V3'], row['V4'],
                                                       row['V5'], row['V6'], row['V7'], row['V8'],
                                                       row['V9'], row['V10'], row['V11'], row['V12'],
                                                       row['V13'], row['V14'],           row['V16'], row['V17']
                                                              ),
                                 axis=1)

# %%
df_low_all_short = df_low_all.head(number_of_rows)
df_high_all_short = df_high_all.head(number_of_rows)
df_medium_all_short = df_medium_all.head(number_of_rows)

# %%
plot_metric(df_low_all_short, df_high_all_short, df_medium_all_short, "WL_mean", "Workload_all", "All: High, Medium & Low, Workload")

# %%
plot_metric(df_low_all_short, df_high_all_short, df_medium_all_short, "S_mean", "Stress_all", "All: High, Medium & Low, Stress")

# %%
plot_metric(df_low_all_short, df_high_all_short, df_medium_all_short, "V_mean", "Vigilance_all", "All: High, Medium & Low, Vigilance")
